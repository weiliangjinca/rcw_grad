# %%
import autograd.numpy as np
from autograd import grad
import nlopt, numpy as npf
import matplotlib.pyplot as plt

import sys
sys.path.append('../')

import use_autograd
use_autograd.use = 1
import rcwa
from utils import test_grad

# %%
t = 59e-9
Period = 2e-6

c0 = 299792458
rho = 2.329e3
mp = 1e-4;
I = 1e10;
A = 10
vf = 0.2*c0
lam0 = 1.2e-6

N = 5
v = np.linspace(0,vf,N)
freq_list = np.sqrt((c0-v)/(c0+v))
gamma = 1./np.sqrt(1-(v/c0)**2)

Nx = 50
Ny = 50

# %%
nG = 51
# lattice vector
Lx = Period/lam0
Ly = Period/lam0
L1 = [Lx,0.]
L2 = [0.,Ly]

# planewave excitation
p_amp = 0.
s_amp = 1.
p_phase = 0.
s_phase = 0.
# frequency and angles
theta = 0.
phi = 0.

# now consider three layers: vacuum + patterned + vacuum
epsuniform1 = 1.
epsdiff = 11.3
epsbkg = 1
epsuniform3 = 1.

thick1 = 1.
thick2 = t/lam0
thick3 = 1.

# %%
ctrl = 0
vec = []
def fun_Distance(dof,Qabs):
    mT = mp + t*A*rho*np.mean(dof)

    R = np.array([])
    for freq in freq_list:
        freqcmp = freq*(1+1j/2/Qabs)
        obj = rcwa.RCWA_obj(nG,L1,L2,freqcmp,theta,phi,verbose=0)
        obj.Add_LayerUniform(thick1,epsuniform1)
        obj.Add_LayerGrid(thick2,epsdiff,epsbkg,Nx,Ny)
        obj.Add_LayerUniform(thick3,epsuniform3)
        obj.Init_Setup(Gmethod=0)

        obj.MakeExcitationPlanewave(p_amp,p_phase,s_amp,s_phase,order = 0)
        obj.GridLayer_getDOF(dof)
        Rtmp,_ = obj.RT_Solve()

        R = np.append(R,Rtmp)

    integrand = mT/R*gamma*v/(1-v/c0)**2
    #D = c0/2/I/A*np.trapz(integrand,x=v)/1e9
    D = c0/2/I/A*(np.sum(integrand)-integrand[0]/2-integrand[-1]/2)*(v[1]-v[0])/1e9

    if 'autograd' not in str(type(D)):
        global ctrl
        global vec
        vec = npf.copy(dof)
        
        print ctrl,np.mean(R),D
        if npf.mod(ctrl,10)==0:
            plt.figure();
            plt.imshow(np.reshape(dof,(Nx,Ny)))
            plt.colorbar()
            plt.show()
            
        ctrl +=1
    return D

# %%
Qabs = np.inf
fun = lambda dof: fun_Distance(dof,Qabs)
grad_fun = grad(fun)

x = np.random.random(Nx*Ny)
test_grad(fun,grad_fun,x,1e-5,0)
# Out:
# 2 0.3463156203042671 8.89065700408092
# 3 0.34631562566095 8.890656969523507
# Finite difference =  -0.003455741293123537 , Auto =  -0.0034557486137955767

# %% [markdown]
# # Qabs = 20

# %%
Qabs = 20.
fun = lambda dof: fun_Distance(dof,Qabs)
grad_fun = grad(fun)
def fun_nlopt(dof,gradn):
    gradn[:] = grad_fun(dof)
    return fun(dof)

ndof = Nx*Ny
#init = np.ones(ndof)
init = np.random.random(ndof)
lb=np.zeros(ndof,dtype=float)
ub=np.ones(ndof,dtype=float)

opt = nlopt.opt(nlopt.LD_MMA, ndof)
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)

opt.set_xtol_rel(1e-5)
opt.set_maxeval(100)

opt.set_min_objective(fun_nlopt)
x = opt.optimize(init)
# Out:
# 0 0.24918443535351634 11.947396798919941
# 1 0.24975865569252723 11.938087313895688
# 2 0.255203031985365 11.85255085423811
# 3 0.30246818585280955 11.275618439190811
# 4 0.3679683717533194 10.201031135720736
# 5 0.25594439740898295 10.103658093417785
# 6 0.43820822773076307 7.7410200624080865
# 7 0.4397120432963824 7.214798195875821
# 8 0.4222063978306065 6.61788683782888
# 9 0.4218813071901839 6.013540488346813
# 10 0.44973732013448176 5.2679347687487725
# 11 0.47536939497952757 4.704681311800428
# 12 0.4872026381079653 4.4210412174889
# 13 0.48943391483202703 4.298950785794079
# 14 0.4920490327042272 4.250655954375953
# 15 0.4959719078419191 4.223343566489679
# 16 0.4902116336594231 4.212920437559266
# 17 0.49064301351436823 4.208574329380594
# 18 0.49026336860796726 4.209402181151457
# 19 0.4905817551150059 4.206317279038587
# 20 0.49154389255893227 4.205245630184452
# 21 0.4923103723514555 4.204797206862985
# 22 0.4948844384233081 4.204046457209414
# 23 0.498860924832058 4.203338457889078
# 24 0.499222720289706 4.2044963921719445
# 25 0.4991420247524904 4.2031604343383515
# 26 0.5002146465415921 4.202830957403965
# 27 0.5008602371120986 4.202654413809159
# 28 0.5037773207578834 4.201546891389312
# 29 0.5083913103439384 4.197775388968363
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-c22343e1e6c3> in <module>()
#      20
#      21 opt.set_min_objective(fun_nlopt)
# ---> 22 x = opt.optimize(init)
#
# /opt/anaconda2/lib/python2.7/site-packages/nlopt.pyc in optimize(self, *args)
#     258         try: self.this.append(this)
#     259         except: self.this = this
# --> 260     def optimize(self, *args): return _nlopt.opt_optimize(self, *args)
#     261     def last_optimize_result(self): return _nlopt.opt_last_optimize_result(self)
#     262     def last_optimum_value(self): return _nlopt.opt_last_optimum_value(self)
#
# <ipython-input-46-c22343e1e6c3> in fun_nlopt(dof, gradn)
#       3 grad_fun = grad(fun)
#       4 def fun_nlopt(dof,gradn):
# ----> 5     gradn[:] = grad_fun(dof)
#       6     return fun(dof)
#       7
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/wrap_util.pyc in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/differential_operators.pyc in grad(fun, x)
#      23     arguments as `fun`, but returns the gradient instead. The function `fun`
#      24     should be scalar-valued. The gradient has the same type as the argument."""
# ---> 25     vjp, ans = _make_vjp(fun, x)
#      26     if not vspace(ans).size == 1:
#      27         raise TypeError("Grad only applies to real scalar-output functions. "
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/core.pyc in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/tracer.pyc in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/wrap_util.pyc in unary_f(x)
#      13                 else:
#      14                     subargs = subvals(args, zip(argnum, x))
# ---> 15                 return fun(*subargs, **kwargs)
#      16             if isinstance(argnum, int):
#      17                 x = args[argnum]
#
# <ipython-input-46-c22343e1e6c3> in <lambda>(dof)
#       1 Qabs = 20.
# ----> 2 fun = lambda dof: fun_Distance(dof,Qabs)
#       3 grad_fun = grad(fun)
#       4 def fun_nlopt(dof,gradn):
#       5     gradn[:] = grad_fun(dof)
#
# <ipython-input-45-6f1a1280c04b> in fun_Distance(dof, Qabs)
#      14
#      15         obj.MakeExcitationPlanewave(p_amp,p_phase,s_amp,s_phase,order = 0)
# ---> 16         obj.GridLayer_getDOF(dof)
#      17         Rtmp,_ = obj.RT_Solve()
#      18
#
# /Users/weiliang/Desktop/rcw_grad/rcwa.py in GridLayer_getDOF(self, dof)
#     192             self.kp_list[self.id_list[i][1]] = kp
#     193
# --> 194             q,phi = SolveLayerEigensystem(self.omega,self.kx,self.ky,kp,ep2)
#     195             self.q_list[self.id_list[i][1]] = q
#     196             self.phi_list[self.id_list[i][1]] = phi
#
# /Users/weiliang/Desktop/rcw_grad/rcwa.py in SolveLayerEigensystem(omega, kx, ky, kp, ep2)
#     254     M = np.dot(ep2,kp) - kkT
#     255
# --> 256     q,phi = eig(M)
#     257     q = sqrt(q)
#     258     # branch cut choice
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/tracer.pyc in f_wrapped(*args, **kwargs)
#      42             parents = tuple(box._node for _     , box in boxed_args)
#      43             argnums = tuple(argnum    for argnum, _   in boxed_args)
# ---> 44             ans = f_wrapped(*argvals, **kwargs)
#      45             node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46             return new_box(ans, trace, node)
#
# /opt/anaconda2/lib/python2.7/site-packages/autograd/tracer.pyc in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# /opt/anaconda2/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in eig(a)
#    1309         _raise_linalgerror_eigenvalues_nonconvergence)
#    1310     signature = 'D->DD' if isComplexType(t) else 'd->DD'
# -> 1311     w, vt = _umath_linalg.eig(a, signature=signature, extobj=extobj)
#    1312
#    1313     if not isComplexType(t) and all(w.imag == 0.0):
#
# KeyboardInterrupt:

# %% [markdown]
# # Qabs = 100

# %%
Qabs = 100.
fun = lambda dof: fun_Distance(dof,Qabs)
grad_fun = grad(fun)
def fun_nlopt(dof,gradn):
    gradn[:] = grad_fun(dof)
    return fun(dof)

ndof = Nx*Ny
#init = np.ones(ndof)
init = npf.copy(vec)
lb=np.zeros(ndof,dtype=float)
ub=np.ones(ndof,dtype=float)

opt = nlopt.opt(nlopt.LD_MMA, ndof)
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)

opt.set_xtol_rel(1e-5)
opt.set_maxeval(100)

opt.set_min_objective(fun_nlopt)
x = opt.optimize(init)
# Out:
# 30 0.745417422651672 3.0146698475155977
# 31 0.7454184707846843 3.0146686973471017
# 32 0.7454289069000296 3.014657243219712
# 33 0.7455717424627294 3.014500082156763
# 34 0.7465133766027459 3.013431568943697
# 35 0.7467922226331395 3.013106605024443
# 36 0.7467922226331395 3.013106605024443

# %% [markdown]
# # Qabs = 1000

# %%
Qabs = 1000
fun = lambda dof: fun_Distance(dof,Qabs)
grad_fun = grad(fun)
def fun_nlopt(dof,gradn):
    gradn[:] = grad_fun(dof)
    return fun(dof)

ndof = Nx*Ny
#init = np.ones(ndof)
init = npf.copy(vec)
lb=np.zeros(ndof,dtype=float)
ub=np.ones(ndof,dtype=float)

opt = nlopt.opt(nlopt.LD_MMA, ndof)
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)

opt.set_xtol_rel(1e-5)
opt.set_maxeval(100)

opt.set_min_objective(fun_nlopt)
x = opt.optimize(init)
# Out:
# 37 0.8164531018704 2.7951683741794544
# 38 0.8164531018704 2.7951683741794544

# %% [markdown]
# # Qabs = Inf

# %%
Qabs = np.inf
fun = lambda dof: fun_Distance(dof,Qabs)
grad_fun = grad(fun)
def fun_nlopt(dof,gradn):
    gradn[:] = grad_fun(dof)
    return fun(dof)

ndof = Nx*Ny
#init = np.ones(ndof)
init = npf.copy(x)
lb=np.zeros(ndof,dtype=float)
ub=np.ones(ndof,dtype=float)

opt = nlopt.opt(nlopt.LD_MMA, ndof)
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)

opt.set_xtol_rel(1e-5)
opt.set_maxeval(100)

opt.set_min_objective(fun_nlopt)
x = opt.optimize(init)
# Out:
# 0 0.8311223853798549 2.7462382779511056
# 1 0.8311223853798549 2.7462382779511056
